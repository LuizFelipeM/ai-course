# %%
# !pip install transformers

# %%
import transformers
from transformers import pipeline

# %%
generator = pipeline("text-generation", model="pierreguillou/gpt2-small-portuguese")
text = "Um transformers é um grande modelo de linguagem natural"
result = generator(text, max_length=100, do_sample=True)
print(result)
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/510M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/92.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/850k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/508k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Um transformers é um grande modelo de linguagem natural que facilita a compreensão do conhecimento humano como:\n\n\nUma outra parte importante deste tipo de linguagem, e usada na maioria dos organismos vivos, é desenvolvida pela própria humanidade, tendo desenvolvido-se por diversos povos por milênios. Alguns desses povos não foram ou não humanos, ou até mesmo chegaram a nós via sinais e imagens, que ajudam a compreender em sua visão as mensagens e as ações de um indivíduo, e assim por diante, temos hoje uma outra'}]
